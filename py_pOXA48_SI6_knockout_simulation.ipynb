# %%
import numpy as np
import os
import csv
import sys
import matplotlib.pyplot as plt
import colorcet as cc
import time
import multiprocessing
import random
from tabulate import tabulate
import itertools
import os
import pickle

# %% [markdown]
# ## __SI:__ Antimicrobial resistance level and conjugation permissiveness shape plasmid distribution in clinical enterobacteria
#
# ###6. Computer experiment: Iterative knock-out simulations
# This Jupyter Notebook documents the implementation of the iterative knock-out simulations used in our study. In this approach, strains were randomly and sequentially removed from a community initially composed of 20 strains. After each removal, we re-initialized the simulation with the remaining strains, maintaining the initial total density of bacteria and the initial fraction of plasmid-bearing bacteria as in the multistrain dose-response assays.
#
# The key measurement following each removal was the change in plasmid stability in the community, monitored through the densities of remaining strains and their plasmid-bearing fractions. This approach allowed us to identify strains whose removal significantly impacted plasmid stability, indicating that these strains formed successful associations with the plasmid, contributing to the persistence of antibiotic resistance within the community.

# %% [markdown]
# ### Experimental parameters

# %%
sys.path.insert(0, 'src/')
from pOXA48_S1 import *
from pOXA48_S2 import *
from pOXA48_S3 import *

# %run src/pOXA48_parameters
print_expe_params(expe_params)
# Out:
# Experimental Parameters:
# ------------------------------------------------
# 	Initial bacterial density (B0): 1000000.0
# 	Maximum drug concentration (A_max): 131072
# 	Antibiotic degradation rates (alphas): [1.e-10 1.e-12]
# 	Length of experiment (T): 24
# 	Initial resource concentration (S0): 1.0
# 	Resource decay rate (d): 0.1
# 	Extinction threshold: 1.0
# ------------------------------------------------

# %% [markdown]
# ### Model parameters

# %%
model_params = import_model_params("%smodel_params.csv"%(dataPath), expe_params)
display_model_params_stats(model_params, strains_subset)
# Out:
# ╒═════════╤═════════════╤═══════════════════════╤═════════════════════════════════╤═════╕
# │ Group   │ Parameter   │ Mean                  │ Range                           │ N   │
# ╞═════════╪═════════════╪═══════════════════════╪═════════════════════════════════╪═════╡
# │ E-TC    │ conj_rate   │ nan                   │ (nan, nan)                      │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-TC    │ VKm         │ 5.931e-10             │ (3.79e-10, 7.6e-10)             │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-TC    │ rho         │ 948158352.0           │ (550386500.0, 1121715175.0)     │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-TC    │ seg_rate    │ 0.0020000000000000005 │ (0.002, 0.002)                  │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-TC    │ kappa       │ 0.053515625           │ (0.00390625, 0.0625)            │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │         │             │                       │                                 │     │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-WT    │ conj_rate   │ -11.1913602           │ (-12.064055, -10.16414)         │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-WT    │ VKm         │ 5.826e-10             │ (4.15e-10, 7.37e-10)            │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-WT    │ rho         │ 914429400.75          │ (678608700.0, 1040166000.0)     │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-WT    │ seg_rate    │ 0.0020000000000000005 │ (0.002, 0.002)                  │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ E-WT    │ kappa       │ 0.00037841796875      │ (0.0001220703125, 0.0009765625) │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │         │             │                       │                                 │     │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-TC    │ conj_rate   │ nan                   │ (nan, nan)                      │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-TC    │ VKm         │ 5.33e-10              │ (4.16e-10, 6.64e-10)            │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-TC    │ rho         │ 879079600.0           │ (756823200.0, 1077144250.0)     │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-TC    │ seg_rate    │ 0.0020000000000000005 │ (0.002, 0.002)                  │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-TC    │ kappa       │ 0.28828125            │ (0.0078125, 0.5)                │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │         │             │                       │                                 │     │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-WT    │ conj_rate   │ -11.3779437           │ (-14.6, -9.840598)              │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-WT    │ VKm         │ 5.774999999999999e-10 │ (3.65e-10, 8.67e-10)            │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-WT    │ rho         │ 832552906.0           │ (660056000.0, 1008177000.0)     │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-WT    │ seg_rate    │ 0.0020000000000000005 │ (0.002, 0.002)                  │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │ K-WT    │ kappa       │ 0.00079345703125      │ (0.0001220703125, 0.001953125)  │ 10  │
# ├─────────┼─────────────┼───────────────────────┼─────────────────────────────────┼─────┤
# │         │             │                       │                                 │     │
# ╘═════════╧═════════════╧═══════════════════════╧═════════════════════════════════╧═════╛

# %% [markdown]
# The computer experiments involve running a series of simulations on bacterial communities composed of varying strains and subjected to a range of antibiotic concentrations. Our methodology is aimed at evaluating how an increase in the number of strains enhances the likelihood of establishing a successful plasmid-host relationship that enables the plasmid to persist in that environment. By repeating these experiments across different community sizes and strengths of selection, we can evaluate the conditions under which a plasmid is maintained in the population.
#
# The collected data, encapsulating the distribution of the plasmid across strains under different environmental pressures, is saved for further analysis and visualization.

# %%
num_days = 10
num_expe = 100
type_experiment='invasion'

# %%
powers = np.arange(13, 20.0, 1.0)  # array of powers of two exponents
Amax_values=[0.0] #np.power(2.0, powers)  # calculate 2 raised to each exponent

# %%
def simulate_environment_multistrain(model_params, istrains, E):
    """
    Simulates the bacterial dynamics for multiple strains in a specific environmental condition.

    Parameters:
    model_params: dict
        The dictionary containing model parameters.
    istrains: list
        A list of the strains that should be included in the simulation.
    E: array
        The environmental data for the simulation.

    Returns:
    Btot: array
        The total bacterial density at the end of the simulation.
    BpE, BpK: arrays
        The densities of plasmid-bearing strains with and without the resistance gene, respectively.
    BfE, BfK: arrays
        The densities of plasmid-free strains with and without the resistance gene, respectively.
    freqpE, freqpK: arrays
        The frequencies of plasmid-bearing strains with and without the resistance gene, respectively.
    times_list, ys_list: lists
        The time points and corresponding solution vectors at which the solution was evaluated.
    strains_params_list: list
        A list of the strain-specific parameters for each of the strains included in the simulation.
    """
    print('.', end="", flush=True)

    # Simulate transfers for the given strains and environment
    times_list, ys_list, strains_params_list = simulateTransfers_multistrain(model_params, istrains, E, type_experiment)

    # Extract the final time point and corresponding solution vectors
    final_times, final_ys = get_final_points(times_list, ys_list)

    # Analyze the simulation results to get bacterial densities and frequencies
    Btot, BpE, BpK, BfE, BfK, freqpE, freqpK  = analyze_simulation(model_params, istrains, final_ys)

    return Btot, BpE, BpK, BfE, BfK, freqpE, freqpK, times_list, ys_list, strains_params_list

def simulate_environments_multistrain(model_params, istrains, Es):
    """
    Simulates the bacterial dynamics for multiple strains across different environments.

    This function iterates over the given environments, simulating the dynamics of the bacterial strains
    in each environment and collecting the results.

    Parameters:
    model_params: dict
        The dictionary containing model parameters.
    istrains: list
        A list of the strains that should be included in the simulation.
    Es: list of arrays
        A list of environmental data for the simulation, each array corresponds to a different environment.

    Returns:
    Btots: list of arrays
        The total bacterial density at the end of each simulation.
    BpEs, BpKs: lists of arrays
        Lists of the densities of plasmid-bearing strains with and without the resistance gene, respectively.
    BfEs, BfKs: lists of arrays
        Lists of the densities of plasmid-free strains with and without the resistance gene, respectively.
    freqpEs, freqpKs: lists of arrays
        Lists of the frequencies of plasmid-bearing strains with and without the resistance gene, respectively.
    ts: list of lists
        Lists of the time points at which the solution was evaluated in each simulation.
    ys: list of lists
        Lists of the corresponding solution vectors for each time point in each simulation.
    params: list of lists
        Lists of the strain-specific parameters for each of the strains included in the simulation.
    """
    freqpEs = []
    freqpKs = []
    BpEs=[]
    BpKs=[]
    BfEs=[]
    BfKs=[]
    Btots=[]
    ts=[]
    ys=[]
    params=[]
    for E in Es:
        Btot, BpE, BpK, BfE, BfK, freqpE, freqpK, times_list, ys_list, params_list = simulate_environment_multistrain(model_params, istrains, E)
        freqpEs.append(freqpE)
        freqpKs.append(freqpK)
        BfEs.append(BfE)
        BfKs.append(BfK)
        BpEs.append(BpE)
        BpKs.append(BpK)
        Btots.append(Btot)
        ts.append(times_list)
        ys.append(ys_list)
        params.append(params_list)

    return Btots, BpEs, BpKs, BfEs, BfKs, freqpEs, freqpKs, ts, ys, params

# %%
def get_sequences_from_files(directory, length=None):
    """
    Extracts sequences of integers from the names of the files in a directory.

    This function looks for files with names that start with "sim_Es_" and end with ".pkl", then
    extracts a sequence of integers from the rest of the filename. It assumes that the integers
    are separated by underscores.

    Parameters:
    directory: str
        The path to the directory containing the files.
    length: int, optional
        The length of the sequences to look for. If specified, only sequences of this length are returned.
        If not specified, sequences of any length are returned.

    Returns:
    sequences: list of lists
        A list of the sequences that were found. Each sequence is represented as a list of integers.
    """
    sequences = []

    print(directory)
    for filename in os.listdir(directory):
        if filename.startswith("sim_Es_") and filename.endswith(".pkl"):
            sequence = filename[len("sim_Es_"):-len(".pkl")]
            sequence = list(map(int, sequence.split('_')))

            if length is None or len(sequence) == length:
                sequences.append(sequence)

    return sequences

# %%
def simulate_subset(model_params, istrains=[], Es=[]):
    """
    Simulates multiple bacterial strain growth for subsets of strains in varying environments.

    This function simulates bacterial growth for subsets of the given strains in the provided
    environments. It outputs the total bacterial biomass, plasmid-bearing and plasmid-free biomass
    for both environment types, and the frequency of plasmid-bearing bacteria for both environment types.

    Parameters:
    model_params: dict
        The dictionary containing model parameters.
    istrains: list, optional
        List of strain indexes to be simulated.
    Es: list, optional
        List of environments for the simulation.

    Returns:
    istrains_all, Es_all, Btots_all, BpEs_all, BpKs_all, BfEs_all, BfKs_all, freqpEs_all, freqpKs_all, ts_all, ys_all, params_all:
        Lists containing, respectively, all strain subsets, all environments, total bacterial biomass, plasmid-bearing
        biomass for both environments, plasmid-free biomass for both environments, frequency of plasmid-bearing
        bacteria for both environments, simulation times, system state for each time step, and model parameters.
    """
    freqpEs_all=[]
    freqpKs_all=[]
    Btots_all=[]
    BpEs_all=[]
    BpKs_all=[]
    BfEs_all=[]
    BfKs_all=[]
    istrains_all=[]
    Es_all=[]
    ys_all=[]
    ts_all=[]
    params_all=[]


    for subset_length in range(1, len(istrains) + 1):
      freqpEs = []
      freqpKs = []
      Btots=[]
      BpEs=[]
      BpKs=[]
      BfEs=[]
      BfKs=[]
      ys=[]
      ts=[]
      params=[]

      subset = istrains[:subset_length]
      print(f"\t{subset}: ", end="", flush=True)

      str_subset = [str(x) for x in subset]  # Convert all elements to string
      sim_lbl = "_".join(str_subset)  # Join elements with "_"
      fileName = "sim_Es_%s.pkl" % sim_lbl  # Construct the filename

      if os.path.isfile("%s%s"%(runPathN, fileName)):

        istrains_subset, Es, Btot, BpEs, BpKs, BfEs, BfKs, freqpEs, freqpKs, ts, ys, params = load_simulation_results("%s%s"%(runPathN, fileName))
        print(" Loading %s%s"%(runPathN, fileName))
      else:

        # Iterate over each E in Es
        for E in Es:

              # Run the simulation for the current E and subset
              this_Btot, this_BpEs, this_BpKs, this_BfEs, this_BfKs, this_freqpEs, this_freqpKs, this_ts, this_ys, this_params = simulate_environment_multistrain(model_params, subset, E)
              Btots.append(this_Btot)
              BpEs.append(this_BpEs)
              BpKs.append(this_BpKs)
              BfEs.append(this_BfEs)
              BfKs.append(this_BfKs)
              freqpEs.append(this_freqpEs)
              freqpKs.append(this_freqpKs)
              ts.append(this_ts)
              ys.append(this_ys)
              params.append(this_params)

              if np.any(this_freqpEs+this_freqpKs)>0.5:
                print('*', end="", flush=True)
              else:
                print('o', end="", flush=True)

        save_simulation_results("%s%s"%(runPathN, fileName), subset, Es, Btots, BpEs, BpKs, BfEs, BfKs, freqpEs, freqpKs, ts, ys, params)
        print(" Saving %s%s"%(runPathN,fileName))

      istrains_all.append(subset)
      Btots_all.append(Btots)
      Es_all.append(Es)
      BpEs_all.append(BpEs)
      BpKs_all.append(BpKs)
      freqpEs_all.append(freqpEs)
      ts_all.append(ts)
      ys_all.append(ys)
      params_all.append(params)

    return istrains_all, Es_all, Btots_all, BpEs_all, BpKs_all, BfEs_all, BfKs_all, freqpEs_all, freqpKs_all, ts_all, ys_all, params_all

# %%
def select_random_elements(strains_subset, num_elements):
    """
    Selects a specified number of random elements from a given list.

    This function randomly selects a specified number of elements from the provided list,
    without replacement. The function is primarily used for selecting a subset of bacterial strains.

    Parameters:
    strains_subset: list
        List from which elements are to be randomly selected.
    num_elements: int
        Number of elements to be randomly selected from the list.

    Returns:
    random_elements: list
        List of randomly selected elements.
    """

    random_elements = random.sample(strains_subset, num_elements)
    return random_elements

# %%
def run_experiment(model_params, strains_subset, num_expe, istrains_done):
    """
    Runs the entire simulation experiment for a given set of strains.

    This function performs a specified number of simulation experiments on a provided subset of strains.
    Each experiment runs a series of simulations using a set of strains chosen either from a list of
    already completed strains (if available) or randomly selected from the subset.

    Parameters:
    model_params: dict
        The dictionary containing model parameters.
    strains_subset: list
        List containing all potential strains that can be used in the simulation.
    num_expe: int
        Number of simulation experiments to be performed.
    istrains_done: list
        List of strain sets for which simulations have already been completed.

    Returns:
    Various lists of experiment results including total biomass, total plasmid-bearing and
    plasmid-free strains, total plasmid frequency, specific time points, states at those time
    points, and strain-specific parameters used.
    """

    max_strains = len(strains_subset)

    istrains_expe = []
    Es_expe = []
    Btots_expe = []
    BpEs_expe = []
    BpKs_expe = []
    BfEs_expe = []
    BfKs_expe = []
    freqpEs_expe = []
    freqpKs_expe = []
    ts_expe = []
    ys_expe = []
    params_expe = []

    for i in range(num_expe):
        start_time = time.time()  # Record the start time

        if i < len(istrains_done):
            istrains = istrains_done[i]
            print('* ', i, ': istrains =', istrains)
        else:
            istrains = select_random_elements(strains_subset, max_strains)
            print('** ', i, ': istrains =', istrains)

        # Run the simulations
        istrains_subset, Es_subset, Btots_subset, BpEs_subset, BpKs_subset, BfEs_subset, BfKs_subset, freqpEs_subset, freqpKs_subset, ts_subset, ys_subset, params_subset = simulate_subset(model_params, istrains, As)

        istrains_expe.append(istrains_subset)
        Es_expe.append(Es_subset)
        Btots_expe.append(Btots_subset)
        BpEs_expe.append(BpEs_subset)
        BpKs_expe.append(BpKs_subset)
        BfEs_expe.append(BfEs_subset)
        BfKs_expe.append(BfKs_subset)
        freqpEs_expe.append(freqpEs_subset)
        freqpKs_expe.append(freqpKs_subset)
        ts_expe.append(ts_subset)
        ys_expe.append(ys_subset)
        params_expe.append(params_subset)

        end_time = time.time()  # Record the end time
        elapsed_time = end_time - start_time  # Calculate the elapsed time

        print("Total time elapsed: {:.2f} seconds".format(elapsed_time))

    return istrains_expe, Es_expe, Btots_expe, BpEs_expe, BpKs_expe, BfEs_expe, BfKs_expe, freqpEs_expe, freqpKs_expe, ts_expe, ys_expe, params_expe

# %%
import math

As_norm=np.ones(num_days)
for Amax in Amax_values:
  #print("******** Amax=2**%s"%math.log2(Amax))

  As = [[Amax * e for e in As_norm]]

  expeLabel='%s_N%s_A%se-2'%(str_E, num_days, int(Amax*100))
  runPathN = path+'runs/N'+str(num_days)+'/'+expeLabel+'/'
  print("runPath=%s"%runPathN)


  if not os.path.exists(runPathN):
    os.makedirs(runPathN)

  istrains_done = get_sequences_from_files(runPathN, length=len(strains_subset))
  istrains_done = istrains_done[:num_expe]

  print(istrains_done)


  istrains_expe, Es_expe, Btots_expe, BpEs_expe, BpKs_expe, BfEs_expe, BfKs_expe, freqpEs_expe, freqpKs_expe, ts_expe, ys_expe, params_expe = run_experiment(model_params, strains_subset, num_expe, istrains_done)
# Out:
# runPath=./runs/N10/constant_N10_A0e-2/
# ./runs/N10/constant_N10_A0e-2/
# [[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25, 6, 9, 24], [43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39, 21, 26, 6], [26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1, 29, 2, 45], [45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15, 43, 39, 25], [29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1, 11, 25, 21], [43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24, 6, 38, 18], [21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1, 29, 25, 6], [41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26, 9, 37, 45], [20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15, 21, 45, 43], [2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43, 25, 34, 39], [37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11, 24, 18, 43], [37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26, 1, 9, 24], [15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1, 26, 18, 6], [43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34, 9, 45, 6], [2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29, 34, 38, 43], [37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11, 34, 41, 9], [38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24, 26, 37, 45], [18, 1, 2, 9, 41, 24, 21, 38, 15, 39, 29, 20, 37, 45, 11, 26, 43, 25, 6, 34], [15, 37, 24, 9, 25, 18, 26, 29, 20, 38, 21, 1, 2, 41, 43, 11, 6, 45, 34, 39], [39, 29, 38, 15, 24, 9, 41, 34, 43, 37, 20, 45, 1, 11, 18, 21, 26, 6, 25, 2], [25, 6, 24, 15, 18, 11, 26, 29, 20, 21, 37, 34, 2, 38, 9, 39, 41, 1, 45, 43], [15, 39, 2, 37, 43, 6, 20, 34, 21, 45, 1, 9, 25, 24, 11, 29, 26, 38, 41, 18], [25, 6, 9, 41, 15, 45, 38, 24, 20, 2, 43, 11, 29, 37, 18, 34, 1, 26, 39, 21], [1, 18, 34, 11, 26, 15, 2, 45, 9, 37, 25, 38, 41, 21, 39, 24, 43, 20, 6, 29], [18, 39, 43, 41, 11, 38, 34, 1, 25, 26, 9, 37, 45, 20, 21, 2, 24, 6, 15, 29], [20, 25, 26, 29, 43, 45, 21, 34, 38, 24, 2, 11, 15, 18, 37, 9, 1, 39, 41, 6], [20, 41, 38, 11, 18, 39, 2, 34, 29, 6, 1, 45, 15, 25, 26, 24, 43, 21, 9, 37], [25, 45, 20, 37, 26, 29, 6, 9, 39, 18, 11, 24, 2, 43, 21, 41, 1, 15, 34, 38], [21, 29, 45, 37, 11, 9, 20, 6, 2, 1, 38, 15, 41, 24, 26, 39, 18, 34, 25, 43], [21, 11, 2, 26, 45, 18, 29, 6, 39, 20, 24, 34, 37, 9, 15, 43, 25, 41, 1, 38], [37, 9, 34, 20, 39, 26, 43, 2, 21, 11, 41, 25, 45, 18, 24, 15, 38, 1, 6, 29], [34, 25, 6, 21, 20, 26, 41, 43, 39, 37, 11, 2, 1, 38, 45, 15, 24, 18, 9, 29], [18, 37, 38, 39, 34, 1, 43, 45, 29, 41, 25, 24, 20, 21, 15, 6, 26, 9, 11, 2], [9, 20, 37, 29, 15, 1, 45, 34, 11, 18, 6, 21, 25, 24, 2, 39, 26, 43, 41, 38], [9, 18, 45, 24, 11, 39, 41, 20, 26, 2, 6, 29, 25, 43, 38, 21, 34, 1, 15, 37], [25, 15, 11, 41, 18, 37, 24, 43, 45, 39, 38, 1, 9, 29, 2, 6, 26, 21, 34, 20], [45, 26, 21, 25, 20, 24, 6, 11, 43, 9, 37, 1, 34, 15, 41, 18, 38, 2, 29, 39], [20, 11, 1, 38, 18, 21, 45, 34, 25, 37, 6, 39, 41, 43, 9, 26, 24, 29, 2, 15], [37, 45, 18, 43, 2, 26, 38, 39, 34, 20, 9, 21, 29, 11, 25, 41, 1, 15, 6, 24], [9, 20, 15, 2, 24, 29, 38, 37, 43, 39, 45, 1, 25, 21, 26, 41, 18, 11, 6, 34], [29, 20, 25, 1, 2, 18, 39, 41, 43, 26, 21, 45, 24, 37, 6, 34, 9, 11, 15, 38], [24, 37, 21, 38, 39, 45, 26, 1, 9, 25, 34, 2, 11, 6, 43, 29, 15, 20, 18, 41], [38, 6, 15, 25, 26, 24, 37, 9, 41, 11, 45, 1, 2, 39, 20, 43, 18, 34, 29, 21], [29, 45, 37, 9, 11, 18, 34, 41, 20, 6, 25, 24, 43, 21, 38, 15, 26, 2, 1, 39], [45, 34, 9, 11, 1, 29, 18, 2, 38, 20, 15, 25, 21, 37, 24, 39, 6, 43, 26, 41], [20, 39, 1, 45, 37, 38, 34, 25, 15, 24, 11, 6, 18, 29, 2, 9, 26, 21, 43, 41], [24, 11, 34, 43, 21, 29, 25, 38, 9, 2, 18, 26, 37, 41, 20, 39, 1, 15, 6, 45], [45, 26, 37, 43, 20, 6, 25, 2, 1, 15, 41, 11, 34, 29, 24, 18, 39, 9, 21, 38], [11, 21, 6, 24, 45, 38, 25, 18, 20, 15, 9, 41, 29, 34, 43, 2, 1, 26, 39, 37], [43, 21, 41, 37, 24, 26, 34, 38, 1, 6, 11, 15, 2, 45, 29, 9, 25, 18, 20, 39], [24, 11, 37, 26, 21, 41, 39, 6, 15, 45, 9, 2, 20, 1, 29, 18, 43, 25, 34, 38], [45, 38, 37, 18, 2, 2 ...
# *  0 : istrains = [18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25, 6, 9, 24]
# 	[18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18.pkl
# 	[18, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11.pkl
# 	[18, 11, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37.pkl
# 	[18, 11, 37, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45.pkl
# 	[18, 11, 37, 45, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15.pkl
# 	[18, 11, 37, 45, 15, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41.pkl
# 	[18, 11, 37, 45, 15, 41, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38_1.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38_1_25.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38_1_25_6.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25, 6, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38_1_25_6_9.pkl
# 	[18, 11, 37, 45, 15, 41, 43, 2, 29, 34, 26, 20, 21, 39, 38, 1, 25, 6, 9, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_18_11_37_45_15_41_43_2_29_34_26_20_21_39_38_1_25_6_9_24.pkl
# Total time elapsed: 54.30 seconds
# *  1 : istrains = [43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39, 21, 26, 6]
# 	[43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43.pkl
# 	[43, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29.pkl
# 	[43, 29, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34.pkl
# 	[43, 29, 34, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11.pkl
# 	[43, 29, 34, 11, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2.pkl
# 	[43, 29, 34, 11, 2, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20.pkl
# 	[43, 29, 34, 11, 2, 20, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37_9.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37_9_39.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37_9_39_21.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39, 21, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37_9_39_21_26.pkl
# 	[43, 29, 34, 11, 2, 20, 41, 25, 1, 18, 38, 45, 24, 15, 37, 9, 39, 21, 26, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_29_34_11_2_20_41_25_1_18_38_45_24_15_37_9_39_21_26_6.pkl
# Total time elapsed: 0.22 seconds
# *  2 : istrains = [26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1, 29, 2, 45]
# 	[26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26.pkl
# 	[26, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41.pkl
# 	[26, 41, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38.pkl
# 	[26, 41, 38, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15.pkl
# 	[26, 41, 38, 15, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20.pkl
# 	[26, 41, 38, 15, 20, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6.pkl
# 	[26, 41, 38, 15, 20, 6, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39_25.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39_25_1.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39_25_1_29.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1, 29, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39_25_1_29_2.pkl
# 	[26, 41, 38, 15, 20, 6, 21, 37, 9, 43, 34, 18, 11, 24, 39, 25, 1, 29, 2, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_26_41_38_15_20_6_21_37_9_43_34_18_11_24_39_25_1_29_2_45.pkl
# Total time elapsed: 0.20 seconds
# *  3 : istrains = [45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15, 43, 39, 25]
# 	[45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45.pkl
# 	[45, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41.pkl
# 	[45, 41, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18.pkl
# 	[45, 41, 18, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2.pkl
# 	[45, 41, 18, 2, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21.pkl
# 	[45, 41, 18, 2, 21, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26.pkl
# 	[45, 41, 18, 2, 21, 26, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38_37.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38_37_15.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38_37_15_43.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15, 43, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38_37_15_43_39.pkl
# 	[45, 41, 18, 2, 21, 26, 29, 9, 20, 11, 34, 24, 1, 6, 38, 37, 15, 43, 39, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45_41_18_2_21_26_29_9_20_11_34_24_1_6_38_37_15_43_39_25.pkl
# Total time elapsed: 0.21 seconds
# *  4 : istrains = [29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1, 11, 25, 21]
# 	[29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29.pkl
# 	[29, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34.pkl
# 	[29, 34, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41.pkl
# 	[29, 34, 41, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45.pkl
# 	[29, 34, 41, 45, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39.pkl
# 	[29, 34, 41, 45, 39, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9.pkl
# 	[29, 34, 41, 45, 39, 9, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20_26.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20_26_1.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20_26_1_11.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1, 11, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20_26_1_11_25.pkl
# 	[29, 34, 41, 45, 39, 9, 15, 2, 24, 6, 18, 38, 43, 37, 20, 26, 1, 11, 25, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_29_34_41_45_39_9_15_2_24_6_18_38_43_37_20_26_1_11_25_21.pkl
# Total time elapsed: 0.69 seconds
# *  5 : istrains = [43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24, 6, 38, 18]
# 	[43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43.pkl
# 	[43, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21.pkl
# 	[43, 21, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34.pkl
# 	[43, 21, 34, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2.pkl
# 	[43, 21, 34, 2, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41.pkl
# 	[43, 21, 34, 2, 41, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25.pkl
# 	[43, 21, 34, 2, 41, 25, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45_11.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45_11_24.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45_11_24_6.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24, 6, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45_11_24_6_38.pkl
# 	[43, 21, 34, 2, 41, 25, 37, 39, 9, 1, 20, 29, 26, 15, 45, 11, 24, 6, 38, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_21_34_2_41_25_37_39_9_1_20_29_26_15_45_11_24_6_38_18.pkl
# Total time elapsed: 0.39 seconds
# *  6 : istrains = [21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1, 29, 25, 6]
# 	[21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21.pkl
# 	[21, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41.pkl
# 	[21, 41, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2.pkl
# 	[21, 41, 2, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37.pkl
# 	[21, 41, 2, 37, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26.pkl
# 	[21, 41, 2, 37, 26, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9.pkl
# 	[21, 41, 2, 37, 26, 9, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20_15.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20_15_1.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20_15_1_29.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1, 29, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20_15_1_29_25.pkl
# 	[21, 41, 2, 37, 26, 9, 34, 39, 45, 38, 18, 24, 43, 11, 20, 15, 1, 29, 25, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_21_41_2_37_26_9_34_39_45_38_18_24_43_11_20_15_1_29_25_6.pkl
# Total time elapsed: 0.37 seconds
# *  7 : istrains = [41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26, 9, 37, 45]
# 	[41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41.pkl
# 	[41, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21.pkl
# 	[41, 21, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39.pkl
# 	[41, 21, 39, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38.pkl
# 	[41, 21, 39, 38, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43.pkl
# 	[41, 21, 39, 38, 43, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34.pkl
# 	[41, 21, 39, 38, 43, 34, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2_20.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2_20_26.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2_20_26_9.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26, 9, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2_20_26_9_37.pkl
# 	[41, 21, 39, 38, 43, 34, 1, 25, 15, 24, 6, 18, 29, 11, 2, 20, 26, 9, 37, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_41_21_39_38_43_34_1_25_15_24_6_18_29_11_2_20_26_9_37_45.pkl
# Total time elapsed: 0.32 seconds
# *  8 : istrains = [20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15, 21, 45, 43]
# 	[20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20.pkl
# 	[20, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2.pkl
# 	[20, 2, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11.pkl
# 	[20, 2, 11, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29.pkl
# 	[20, 2, 11, 29, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25.pkl
# 	[20, 2, 11, 29, 25, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38.pkl
# 	[20, 2, 11, 29, 25, 38, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18_34.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18_34_15.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18_34_15_21.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15, 21, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18_34_15_21_45.pkl
# 	[20, 2, 11, 29, 25, 38, 6, 9, 41, 1, 37, 24, 39, 26, 18, 34, 15, 21, 45, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_20_2_11_29_25_38_6_9_41_1_37_24_39_26_18_34_15_21_45_43.pkl
# Total time elapsed: 0.62 seconds
# *  9 : istrains = [2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43, 25, 34, 39]
# 	[2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2.pkl
# 	[2, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6.pkl
# 	[2, 6, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37.pkl
# 	[2, 6, 37, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21.pkl
# 	[2, 6, 37, 21, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26.pkl
# 	[2, 6, 37, 21, 26, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20.pkl
# 	[2, 6, 37, 21, 26, 20, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29_9.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29_9_43.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29_9_43_25.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43, 25, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29_9_43_25_34.pkl
# 	[2, 6, 37, 21, 26, 20, 11, 1, 18, 15, 38, 41, 45, 24, 29, 9, 43, 25, 34, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_6_37_21_26_20_11_1_18_15_38_41_45_24_29_9_43_25_34_39.pkl
# Total time elapsed: 0.22 seconds
# *  10 : istrains = [37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11, 24, 18, 43]
# 	[37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37.pkl
# 	[37, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26.pkl
# 	[37, 26, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2.pkl
# 	[37, 26, 2, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38.pkl
# 	[37, 26, 2, 38, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15.pkl
# 	[37, 26, 2, 38, 15, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39.pkl
# 	[37, 26, 2, 38, 15, 39, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9_29.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9_29_11.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9_29_11_24.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11, 24, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9_29_11_24_18.pkl
# 	[37, 26, 2, 38, 15, 39, 25, 20, 1, 45, 21, 34, 41, 6, 9, 29, 11, 24, 18, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_26_2_38_15_39_25_20_1_45_21_34_41_6_9_29_11_24_18_43.pkl
# Total time elapsed: 0.22 seconds
# *  11 : istrains = [37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26, 1, 9, 24]
# 	[37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37.pkl
# 	[37, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11.pkl
# 	[37, 11, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29.pkl
# 	[37, 11, 29, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6.pkl
# 	[37, 11, 29, 6, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45.pkl
# 	[37, 11, 29, 6, 45, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15.pkl
# 	[37, 11, 29, 6, 45, 15, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2_43.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2_43_26.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2_43_26_1.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26, 1, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2_43_26_1_9.pkl
# 	[37, 11, 29, 6, 45, 15, 20, 18, 38, 41, 21, 34, 25, 39, 2, 43, 26, 1, 9, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_11_29_6_45_15_20_18_38_41_21_34_25_39_2_43_26_1_9_24.pkl
# Total time elapsed: 0.22 seconds
# *  12 : istrains = [15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1, 26, 18, 6]
# 	[15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15.pkl
# 	[15, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20.pkl
# 	[15, 20, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21.pkl
# 	[15, 20, 21, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39.pkl
# 	[15, 20, 21, 39, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45.pkl
# 	[15, 20, 21, 39, 45, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11.pkl
# 	[15, 20, 21, 39, 45, 11, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34_38.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34_38_1.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34_38_1_26.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1, 26, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34_38_1_26_18.pkl
# 	[15, 20, 21, 39, 45, 11, 25, 29, 2, 24, 37, 43, 41, 9, 34, 38, 1, 26, 18, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_15_20_21_39_45_11_25_29_2_24_37_43_41_9_34_38_1_26_18_6.pkl
# Total time elapsed: 0.22 seconds
# *  13 : istrains = [43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34, 9, 45, 6]
# 	[43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43.pkl
# 	[43, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39.pkl
# 	[43, 39, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24.pkl
# 	[43, 39, 24, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18.pkl
# 	[43, 39, 24, 18, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38.pkl
# 	[43, 39, 24, 18, 38, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25.pkl
# 	[43, 39, 24, 18, 38, 25, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20_11.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20_11_34.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20_11_34_9.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34, 9, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20_11_34_9_45.pkl
# 	[43, 39, 24, 18, 38, 25, 1, 26, 41, 15, 29, 2, 21, 37, 20, 11, 34, 9, 45, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_43_39_24_18_38_25_1_26_41_15_29_2_21_37_20_11_34_9_45_6.pkl
# Total time elapsed: 0.26 seconds
# *  14 : istrains = [2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29, 34, 38, 43]
# 	[2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2.pkl
# 	[2, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9.pkl
# 	[2, 9, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6.pkl
# 	[2, 9, 6, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15.pkl
# 	[2, 9, 6, 15, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26.pkl
# 	[2, 9, 6, 15, 26, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45.pkl
# 	[2, 9, 6, 15, 26, 45, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20_37.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20_37_29.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20_37_29_34.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29, 34, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20_37_29_34_38.pkl
# 	[2, 9, 6, 15, 26, 45, 25, 41, 1, 18, 21, 24, 39, 11, 20, 37, 29, 34, 38, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_2_9_6_15_26_45_25_41_1_18_21_24_39_11_20_37_29_34_38_43.pkl
# Total time elapsed: 0.97 seconds
# *  15 : istrains = [37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11, 34, 41, 9]
# 	[37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37.pkl
# 	[37, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45.pkl
# 	[37, 45, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29.pkl
# 	[37, 45, 29, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43.pkl
# 	[37, 45, 29, 43, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15.pkl
# 	[37, 45, 29, 43, 15, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21.pkl
# 	[37, 45, 29, 43, 15, 21, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39_25.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39_25_11.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39_25_11_34.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11, 34, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39_25_11_34_41.pkl
# 	[37, 45, 29, 43, 15, 21, 20, 38, 2, 6, 1, 24, 18, 26, 39, 25, 11, 34, 41, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37_45_29_43_15_21_20_38_2_6_1_24_18_26_39_25_11_34_41_9.pkl
# Total time elapsed: 0.27 seconds
# *  16 : istrains = [38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24, 26, 37, 45]
# 	[38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38.pkl
# 	[38, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2.pkl
# 	[38, 2, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9.pkl
# 	[38, 2, 9, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15.pkl
# 	[38, 2, 9, 15, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29.pkl
# 	[38, 2, 9, 15, 29, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20.pkl
# 	[38, 2, 9, 15, 29, 20, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25_41.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25_41_24.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25_41_24_26.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24, 26, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25_41_24_26_37.pkl
# 	[38, 2, 9, 15, 29, 20, 6, 43, 18, 39, 11, 34, 21, 1, 25, 41, 24, 26, 37, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_38_2_9_15_29_20_6_43_18_39_11_34_21_1_25_41_24_26_37_45.pkl
# Total time elapsed: 0.48 seconds
# *  17 : istrains = [18, 1, 2, 9, 41, 24, 21, 38, 15, 39, 29, 20, 37, 45, 11, 26, 43, 25, 6, 34]
# ...
# 	[24, 39, 34, 45, 15, 21, 18, 25, 9, 11, 29, 6, 38, 1, 26, 43, 2, 37, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_24_39_34_45_15_21_18_25_9_11_29_6_38_1_26_43_2_37_41.pkl
# 	[24, 39, 34, 45, 15, 21, 18, 25, 9, 11, 29, 6, 38, 1, 26, 43, 2, 37, 41, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_24_39_34_45_15_21_18_25_9_11_29_6_38_1_26_43_2_37_41_20.pkl
# Total time elapsed: 0.28 seconds
# *  94 : istrains = [11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2, 38, 24, 34, 45]
# 	[11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11.pkl
# 	[11, 1]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1.pkl
# 	[11, 1, 43]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43.pkl
# 	[11, 1, 43, 15]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15.pkl
# 	[11, 1, 43, 15, 37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37.pkl
# 	[11, 1, 43, 15, 37, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21.pkl
# 	[11, 1, 43, 15, 37, 21, 29]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25_2.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2, 38]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25_2_38.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2, 38, 24]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25_2_38_24.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2, 38, 24, 34]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25_2_38_24_34.pkl
# 	[11, 1, 43, 15, 37, 21, 29, 26, 41, 9, 6, 39, 18, 20, 25, 2, 38, 24, 34, 45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_1_43_15_37_21_29_26_41_9_6_39_18_20_25_2_38_24_34_45.pkl
# Total time elapsed: 0.28 seconds
# **  95 : istrains = [11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26, 29, 25, 37, 39]
# 	[11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11.pkl
# 	[11, 21]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11_21.pkl
# 	[11, 21, 1]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1.pkl
# 	[11, 21, 1, 15]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15.pkl
# 	[11, 21, 1, 15, 2]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2.pkl
# 	[11, 21, 1, 15, 2, 24]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24.pkl
# 	[11, 21, 1, 15, 2, 24, 18]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45_26.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26, 29]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45_26_29.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26, 29, 25]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45_26_29_25.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26, 29, 25, 37]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45_26_29_25_37.pkl
# 	[11, 21, 1, 15, 2, 24, 18, 20, 6, 9, 34, 41, 38, 43, 45, 26, 29, 25, 37, 39]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_21_1_15_2_24_18_20_6_9_34_41_38_43_45_26_29_25_37_39.pkl
# Total time elapsed: 226.49 seconds
# **  96 : istrains = [37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15, 41, 18, 26, 39]
# 	[37]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_37.pkl
# 	[37, 2]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2.pkl
# 	[37, 2, 1]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1.pkl
# 	[37, 2, 1, 6]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6.pkl
# 	[37, 2, 1, 6, 34]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34.pkl
# 	[37, 2, 1, 6, 34, 21]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21.pkl
# 	[37, 2, 1, 6, 34, 21, 9]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11_15.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15, 41]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11_15_41.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15, 41, 18]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11_15_41_18.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15, 41, 18, 26]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11_15_41_18_26.pkl
# 	[37, 2, 1, 6, 34, 21, 9, 20, 25, 29, 24, 43, 38, 45, 11, 15, 41, 18, 26, 39]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_37_2_1_6_34_21_9_20_25_29_24_43_38_45_11_15_41_18_26_39.pkl
# Total time elapsed: 227.69 seconds
# **  97 : istrains = [11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39, 29, 25, 9, 45]
# 	[11]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_11.pkl
# 	[11, 38]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38.pkl
# 	[11, 38, 37]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37.pkl
# 	[11, 38, 37, 15]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15.pkl
# 	[11, 38, 37, 15, 43]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43.pkl
# 	[11, 38, 37, 15, 43, 41]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41.pkl
# 	[11, 38, 37, 15, 43, 41, 26]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18_39.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39, 29]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18_39_29.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39, 29, 25]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18_39_29_25.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39, 29, 25, 9]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18_39_29_25_9.pkl
# 	[11, 38, 37, 15, 43, 41, 26, 6, 24, 2, 34, 21, 20, 1, 18, 39, 29, 25, 9, 45]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_11_38_37_15_43_41_26_6_24_2_34_21_20_1_18_39_29_25_9_45.pkl
# Total time elapsed: 229.64 seconds
# **  98 : istrains = [45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24, 37, 43, 26, 6]
# 	[45]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_45.pkl
# 	[45, 9]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9.pkl
# 	[45, 9, 11]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11.pkl
# 	[45, 9, 11, 1]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1.pkl
# 	[45, 9, 11, 1, 29]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29.pkl
# 	[45, 9, 11, 1, 29, 41]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41.pkl
# 	[45, 9, 11, 1, 29, 41, 38]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2_24.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24, 37]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2_24_37.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24, 37, 43]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2_24_37_43.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24, 37, 43, 26]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2_24_37_43_26.pkl
# 	[45, 9, 11, 1, 29, 41, 38, 39, 21, 18, 20, 15, 25, 34, 2, 24, 37, 43, 26, 6]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_45_9_11_1_29_41_38_39_21_18_20_15_25_34_2_24_37_43_26_6.pkl
# Total time elapsed: 226.31 seconds
# **  99 : istrains = [39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6, 43, 26, 37, 29]
# 	[39]:  Loading ./runs/N10/constant_N10_A0e-2/sim_Es_39.pkl
# 	[39, 1]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1.pkl
# 	[39, 1, 15]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15.pkl
# 	[39, 1, 15, 41]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41.pkl
# 	[39, 1, 15, 41, 38]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38.pkl
# 	[39, 1, 15, 41, 38, 21]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21.pkl
# 	[39, 1, 15, 41, 38, 21, 24]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45_6.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6, 43]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45_6_43.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6, 43, 26]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45_6_43_26.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6, 43, 26, 37]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45_6_43_26_37.pkl
# 	[39, 1, 15, 41, 38, 21, 24, 34, 11, 20, 25, 2, 18, 9, 45, 6, 43, 26, 37, 29]: .* Saving ./runs/N10/constant_N10_A0e-2/sim_Es_39_1_15_41_38_21_24_34_11_20_25_2_18_9_45_6_43_26_37_29.pkl
# Total time elapsed: 224.68 seconds
